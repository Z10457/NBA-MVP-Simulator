# %%
# Imports
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import chromedriver_autoinstaller
import time
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Ignore warnings to keep output clean
warnings.filterwarnings("ignore")

# Automatically install the correct ChromeDriver for your version of Chrome
chromedriver_autoinstaller.install()

# Optional: test Selenium is working
# driver = webdriver.Chrome()
# driver.get("https://www.basketball-reference.com")
# Out:
# '/Users/zohaib/Desktop/cs projects /nba_project/.venv/lib/python3.9/site-packages/chromedriver_autoinstaller/140/chromedriver'

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import matplotlib.pyplot as plt
import seaborn as sns

mvps = pd.read_csv("mvps.csv")

plt.figure(figsize=(20,20))
sns.countplot(data=mvps, x="Player")
plt.xticks(rotation=90)
plt.title("MVP Awards by Players from (2015-2024)")
plt.show()
